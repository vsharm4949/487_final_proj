# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 40.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 36.4 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 36.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 249 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 43.9 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 36.9 MB/s
# ...
#      |████████████████████████████████| 325 kB 37.1 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 28.2 MB/s
# ...
#      |████████████████████████████████| 181 kB 43.9 MB/s
# ...
#      |████████████████████████████████| 144 kB 49.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...

# %%
from transformers import BertConfig, BertModel
import pandas as pd
from sklearn.model_selection import train_test_split
import torch

# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ## Task 1

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args1 ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 10,
             "overwrite_output_dir": True
            }

# Create a ClassificationModel
model1 = ClassificationModel(
    "bert", "hfl/chinese-roberta-wwm-ext",
    num_labels=2,
    args=train_args1
)
# Out:
# Downloading:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/393M [00:00<?, ?B/s]
# Some weights of the model checkpoint at hfl/chinese-roberta-wwm-ext were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
df_train1 = pd.read_csv("/content/drive/Shareddrives/NLP Final Project/Dataset/balanced_train_task1.csv")
df_test1 = pd.read_csv("/content/drive/Shareddrives/NLP Final Project/Dataset/balanced_test_task1.csv")

df_train1.rename(columns={"joke": "text"}, inplace=True)
df_test1.rename(columns={"joke": "text"}, inplace=True)

df_train1.drop(columns=['id', "Unnamed: 0"], inplace=True)
df_test1.drop(columns=['id', "Unnamed: 0"], inplace=True)

df_train1.head()
# Out:
#                               text  label
# 0       当他们全都被困在一起时，他们为什么称他们为“公寓”？      0
# 1                  总有一个白痴比你指望的还要多。      0
# 2               我们的父母和祖父母是一个更大的威胁！      0
# 3  通过用细条培根覆盖任何切口和放牧，可以对猪进行轻微的皮肤移植。      0
# 4                 有时我们不会想你。和它一起生活。      0

# %%
model1.train_model(df_train1) # TODO: Retrain with 10 epochs
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:586: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
#   0%|          | 0/8000 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ...
# Running Epoch 9 of 10:   0%|          | 0/1000 [00:00<?, ?it/s]
# (10000, 0.14581579655788163)

# %%
from sklearn.metrics import f1_score, accuracy_score


def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='macro')
    
result1, model_outputs1, wrong_predictions1 = model1.eval_model(df_test1, f1=f1_multiclass, acc=accuracy_score)

print(result1)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1427: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# ...
# Running Evaluation:   0%|          | 0/200 [00:00<?, ?it/s]
# {'mcc': 0.5897686915288569, 'tp': 612, 'tn': 659, 'fp': 141, 'fn': 188, 'auroc': 0.8615203124999999, 'auprc': 0.8951371334760065, 'f1': 0.7941974148786981, 'acc': 0.794375, 'eval_loss': 1.9971545416104255}

# %%
torch.save(model1, 'roberta-task1.clf') # Remeber to move file to drive

# %% [markdown]
# ## Task 2

# %%
from simpletransformers.classification import ClassificationModel

# define hyperparameter
train_args2 ={"reprocess_input_data": True,
             "fp16":False,
             "num_train_epochs": 10,
             "overwrite_output_dir": True
            }

# Create a ClassificationModel
model2 = ClassificationModel(
    "bert", "hfl/chinese-roberta-wwm-ext",
    num_labels=3,
    args=train_args2
)

# %%
df_train2 = pd.read_csv("/content/drive/Shareddrives/NLP Final Project/Dataset/balanced_train_task2.csv")
df_test2 = pd.read_csv("/content/drive/Shareddrives/NLP Final Project/Dataset/balanced_test_task2.csv")

df_train2.rename(columns={"joke": "text"}, inplace=True)
df_test2.rename(columns={"joke": "text"}, inplace=True)

df_train2.drop(columns=['id', "Unnamed: 0"], inplace=True)
df_test2.drop(columns=['id', "Unnamed: 0"], inplace=True)

df_train2.head()

# %%
model2.train_model(df_train2) # TODO: retrain macro f1

# %%
from sklearn.metrics import f1_score, accuracy_score


def f1_multiclass(labels, preds):
    return f1_score(labels, preds, average='macro')
    
result2, model_outputs2, wrong_predictions2 = model2.eval_model(df_test2, f1=f1_multiclass, acc=accuracy_score)

print(result2)

# %%
torch.save(model2, 'roberta-task2.clf') # Remeber to move file to drive
